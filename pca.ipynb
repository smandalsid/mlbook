# %%
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("pca_data.csv")

# %%
df2=df.select_dtypes(["int64", "float64"])
# df2.dropna(axis=1, inplace=True)

# %%
df_centered = df2 - df2.mean(axis=0)

# %%
U, s, Vt = np.linalg.svd(df_centered)
m, n = df2.shape

S = np.zeros(df_centered.shape)
S[:n,:] = np.diag(s)
W2 = Vt.T[:, :2]
X2D = df_centered.dot(W2)

# %%
np.allclose(df_centered, U.dot(S).dot(Vt))
# Out:
# True

# %%
X2D
# Out:
#                  0           1
# 0    -14467.115249 -550.618322
# 1    -14466.116273 -550.604193
# 2    -14465.157731 -707.063052
# 3    -14463.888567  -74.452593
# 4    -14463.176689 -170.658429
# ...            ...         ...
# 8613  67642.140981 -134.415353
# 8614  74771.986393 -109.238677
# 8615  75011.992597 -101.460630
# 8616  75091.714884 -135.408178
# 8617  78131.467801 -142.796135
#
# [8618 rows x 2 columns]

# %%
from sklearn.decomposition import PCA
df2=df.select_dtypes(["int64", "float64"])
pca = PCA(n_components=.995)
X2D = pca.fit_transform(df2)

# %%
X2D
# Out:
# array([[-14467.11524897,    550.61832164],
#        [-14466.11627339,    550.60419265],
#        [-14465.15773119,    707.06305236],
#        ...,
#        [ 75011.99259704,    101.46062978],
#        [ 75091.714884  ,    135.40817802],
#        [ 78131.46780148,    142.7961351 ]])

# %% [markdown]
# ASS

# %%
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df=pd.read_csv("pca_data.csv")

# %%
df
# Out:
#          ID                       FoodGroup                ShortDescrip  \
# 0      1001          Dairy and Egg Products            BUTTER,WITH SALT
# 1      1002          Dairy and Egg Products    BUTTER,WHIPPED,WITH SALT
# 2      1003          Dairy and Egg Products        BUTTER OIL,ANHYDROUS
# 3      1004          Dairy and Egg Products                 CHEESE,BLUE
# 4      1005          Dairy and Egg Products                CHEESE,BRICK
# ...     ...                             ...                         ...
# 8613  83110  Finfish and Shellfish Products             MACKEREL,SALTED
# 8614  90240  Finfish and Shellfish Products  SCALLOP,(BAY&SEA),CKD,STMD
# 8615  90480                          Sweets                  SYRUP,CANE
# 8616  90560  Finfish and Shellfish Products                   SNAIL,RAW
# 8617  93600  Finfish and Shellfish Products            TURTLE,GREEN,RAW
#
#                                                 Descrip CommonName MfgName  \
# ...

# %%
df2=df.select_dtypes(["int64", "float64"])

# %%
df2
# Out:
#          ID  Energy_kcal  Protein_g  Fat_g  Carb_g  Sugar_g  Fiber_g  \
# 0      1001        717.0       0.85  81.11    0.06     0.06      0.0
# 1      1002        717.0       0.85  81.11    0.06     0.06      0.0
# 2      1003        876.0       0.28  99.48    0.00     0.00      0.0
# 3      1004        353.0      21.40  28.74    2.34     0.50      0.0
# 4      1005        371.0      23.24  29.68    2.79     0.51      0.0
# ...     ...          ...        ...    ...     ...      ...      ...
# 8613  83110        305.0      18.50  25.10    0.00     0.00      0.0
# 8614  90240        111.0      20.54   0.84    5.41     0.00      0.0
# 8615  90480        269.0       0.00   0.00   73.14    73.20      0.0
# 8616  90560         90.0      16.10   1.40    2.00     0.00      0.0
# 8617  93600         89.0      19.80   0.50    0.00     0.00      0.0
#
#       VitA_mcg  VitB6_mg  VitB12_mcg  ...  Folate_USRDA  Niacin_USRDA  \
# ...

# %%
scalar=StandardScaler()
df2=scalar.fit_transform(df2)

# %%
pca = PCA(n_components=.95)
XD = pca.fit_transform(df2)

# %%
XD
# Out:
# array([[-1.80554524,  0.2517071 ,  0.31665071, ..., -0.10187153,
#          0.49192615,  0.33520905],
#        [-1.80096865,  0.25924199,  0.31978531, ..., -0.08930197,
#          0.4790324 ,  0.33911476],
#        [-1.78228621,  0.23715097,  0.46298659, ..., -0.03952894,
#          0.62532362,  0.4248357 ],
#        ...,
#        [-1.7272676 , -1.36781359, -0.70244475, ...,  1.03569831,
#         -1.31169234,  1.47311499],
#        [ 0.66904555,  0.04077377,  3.26965476, ...,  0.93318824,
#         -2.6526802 ,  2.13982259],
#        [-0.98465111,  0.69198713,  0.63540747, ...,  1.39800667,
#         -0.94728921,  1.4774585 ]])

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.25304587 0.10550742 0.08792296 0.07519006 0.06107181 0.05397614
#  0.04471913 0.0423871  0.03558528 0.0339773  0.02744675 0.02507975
#  0.02322827 0.02143271 0.0189301  0.01654916 0.01459523 0.01317916]

# %%
len(pca.explained_variance_ratio_)
# Out:
# 18

# %%
pcadata=pd.DataFrame(data=XD, columns=["PC"+str(i) for i in range(1,19)])

# %% [markdown]
# REDUCING FROM 39 COLUMNS TO 18 COLUMNS

# %%
pcadata
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -1.805545  0.251707  0.316651 -1.703143  3.487966  0.731642  1.673145
# 1    -1.800969  0.259242  0.319785 -1.720956  3.486187  0.724291  1.660272
# 2    -1.782286  0.237151  0.462987 -2.109329  4.508093  0.830748  1.915314
# 3     0.410383  0.123792  2.564119  0.511609 -0.657072  0.634199  2.724214
# 4     0.449869  0.124971  3.428238  0.353251 -1.025809  0.679079  3.365445
# ...        ...       ...       ...       ...       ...       ...       ...
# 8613  1.016068  2.490844  1.383521  1.652368  1.464841 -0.144134 -0.344691
# 8614 -0.849812  0.779578  1.471074  1.349020 -0.567082 -0.775259 -0.313712
# 8615 -1.727268 -1.367814 -0.702445 -2.563607  0.072745 -2.265426 -0.335945
# 8616  0.669046  0.040774  3.269655 -0.128941  0.589302 -0.312199 -3.444192
# 8617 -0.984651  0.691987  0.635407  0.769217 -0.529850 -0.789459 -0.186106
#
# ...

# %%
pcadata=pd.concat([pcadata,df['FoodGroup']], axis=1)

# %%
pcadata
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -1.805545  0.251707  0.316651 -1.703143  3.487966  0.731642  1.673145
# 1    -1.800969  0.259242  0.319785 -1.720956  3.486187  0.724291  1.660272
# 2    -1.782286  0.237151  0.462987 -2.109329  4.508093  0.830748  1.915314
# 3     0.410383  0.123792  2.564119  0.511609 -0.657072  0.634199  2.724214
# 4     0.449869  0.124971  3.428238  0.353251 -1.025809  0.679079  3.365445
# ...        ...       ...       ...       ...       ...       ...       ...
# 8613  1.016068  2.490844  1.383521  1.652368  1.464841 -0.144134 -0.344691
# 8614 -0.849812  0.779578  1.471074  1.349020 -0.567082 -0.775259 -0.313712
# 8615 -1.727268 -1.367814 -0.702445 -2.563607  0.072745 -2.265426 -0.335945
# 8616  0.669046  0.040774  3.269655 -0.128941  0.589302 -0.312199 -3.444192
# 8617 -0.984651  0.691987  0.635407  0.769217 -0.529850 -0.789459 -0.186106
#
# ...
